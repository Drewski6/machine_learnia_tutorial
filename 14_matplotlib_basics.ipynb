# %% [markdown]
# # MatPlotLib - The Basics

# %% [markdown]
# - MatPlotLib is a library for making nice looking graphs and visuals of our data.
# - In general, people who are new to matplotlib can have problems and sometimes this is due to when people mix methods of using matplotlib.
#     - There are 2 methods:
#         - Object oriented method.
#         - plt.plot method.
#     - It is very important to not mix the two.
# - Using the function plot is more simple and that's what we'll do in this tutorial.

# %%
import numpy as np

# %%
x = np.linspace(0, 2, 10)
y = x**2
print(x)
# Out:
# [0.         0.22222222 0.44444444 0.66666667 0.88888889 1.11111111
#  1.33333333 1.55555556 1.77777778 2.        ]

# %% [markdown]
# ## Method 1 - Pyplot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - To show a nice line graph of our data, we use the plot() method in Jupyter.
# - If we are not in Jupyter, we need to add "plt.show()" to tell the application we're in to draw the graph.

# %%
plt.plot(x, y)
# plt.show()        # Use if not in a Jupyter Notebook.

# %% [markdown]
# - To show a scatter plot, use the method scatter().

# %%
plt.scatter(x, y)

# %% [markdown]
# - In matplotlib there are many other parameters we can adjust for our graphs.
# - The advice of the instructor is to keep it as simple as possible becuase changing too many things can make matplotlib do weird things.
#     - A small example is with the "c" parameter which changed the color.
#     - We also have "wl" for "line width".
#     - Lastly, we have "ls" for "line style".

# %%
plt.plot(x, y, c="red", lw=5, ls="--")

# %% [markdown]
# - Each time that we make a plot, an object called a figure is created. Normally, this is full of default values, but if we initialize the figure before drawing to it, we can also pass characteristics such as size to the figure.
# - To see the difference, open VS Code in full screen. (F11)

# %%
plt.figure(figsize=(12, 8))
plt.plot(x, y)

# %% [markdown]
# - Now that our figure is initialized, we can add to it in subsequent lines of code.
# - Note how if we try to draw (x, x**3), the (x, y) from the previous line of code is retained.
# - We can also add a title and labels with the title(), xlabel(), and ylabel() methods.

# %%
plt.figure(figsize=(12, 8))
plt.plot(x, y)
plt.plot(x, x**3)
plt.title("Chihuahua Stats plz")
plt.xlabel("Size of Chihuahua")
plt.ylabel("Amount of ANNOYING")
# Out:
# Text(0, 0.5, 'Amount of ANNOYING')

# %% [markdown]
# - We can add a label for each line as well by indicating the labels for each plot and using the legend method.
# - lastly, we can use the savefig() method do export our graph to a png file.

# %%
plt.figure(figsize=(12, 8))
plt.plot(x, y, label="Normal Chihuahua", lw=5)
plt.plot(x, x**3, label="My Chihuahua", lw=5)
plt.title("Chihuahua Stats plz", size=30)
plt.xlabel("Size of Chihuahua", size=30)
plt.ylabel("Amount of SHIVERING", size=30) 
plt.legend()
plt.savefig("example_graph.png")

# %% [markdown]
# - We can use subplot as well to display multiple plots at a time.
# - Syntax:
#     - subplot(rows, columns, position)

# %%
plt.subplot(2, 1, 1)
plt.plot(x, y, c="red")
plt.subplot(2, 1, 2)
plt.plot(x, y, c="blue")

# %% [markdown]
# - To summarize:
#     - plt.figure()              - Head
#     - plt.subplot(2, 1, 1)      - Body
#         - plt.plot(...,...)
#         ...
#         - plt.title()
#     - plt.subplot(2, 1, 2)
#         - plt.plot(...,...)
#         ...
#         - plt.title()
#     - plt.show()                - Tail

# %% [markdown]
# ## Method 2 - Object Oriented Programming

# %% [markdown]
# - The instructor says that it's good to know that this method exists but is not necessary to truly learn this because method 1 will take care of 99% of the plotting we need to do.
# - For this reason, I'm not going to take detailed notes, but will leave a link in case I want to come back to this.
# - {{https://youtu.be/O_OeWxpnUc0?list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&t=800}}

# %%
fig, ax = plt.subplots(2, 1, sharex=True)
ax[0].plot(x, y)
ax[1].plot(x, np.sin(x))
plt.show()
